# %%
import numpy as np

# %%
N = 1000

# %%
random_function = np.random.randint(1, 1000 + 1, size=1000)

# %%
sorted(list(random_function))
# Out:
# [1,
#  5,
#  7,
#  8,
#  10,
#  10,
#  10,
#  10,
#  11,
#  12,
#  12,
#  13,
#  13,
#  19,
#  20,
#  21,
#  21,
#  22,
#  25,
#  26,
#  26,
#  26,
#  26,
#  30,
#  31,
#  32,
#  39,
#  40,
#  41,
#  41,
#  42,
#  43,
#  45,
#  45,
#  46,
#  47,
#  49,
#  49,
#  51,
#  51,
#  53,
#  53,
#  55,
#  55,
#  55,
#  57,
#  58,
#  58,
#  59,
#  59,
#  59,
#  60,
#  60,
#  60,
#  61,
#  63,
#  64,
#  64,
#  65,
#  66,
#  67,
#  72,
#  73,
#  76,
#  77,
#  78,
#  79,
#  82,
#  82,
#  84,
#  84,
#  87,
#  88,
#  88,
#  89,
#  89,
#  89,
#  90,
#  90,
#  90,
#  90,
#  91,
#  91,
#  91,
#  94,
#  94,
#  94,
#  94,
#  94,
#  95,
#  95,
#  95,
#  96,
#  97,
#  97,
#  98,
#  99,
#  100,
#  104,
#  104,
#  107,
#  108,
#  109,
#  110,
#  110,
#  110,
#  112,
#  113,
#  113,
#  113,
#  114,
#  115,
#  115,
#  116,
#  116,
#  117,
#  118,
#  118,
#  119,
#  119,
#  120,
#  121,
#  123,
#  124,
#  124,
#  125,
#  126,
#  126,
#  130,
#  131,
#  133,
#  134,
#  135,
#  135,
#  137,
#  137,
#  140,
# ...
